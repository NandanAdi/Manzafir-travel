# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Dense,Activation,Dropout
from keras.layers import LSTM
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn import svm
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
from xgboost import XGBClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import accuracy_score
from sklearn.tree import DecisionTreeClassifier
from keras.callbacks import EarlyStopping
import math
import os
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.metrics.pairwise import linear_kernel, cosine_similarity
from nltk.stem.snowball import SnowballStemmer
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.corpus import wordnet
from nltk.stem import WordNetLemmatizer

# %%
hotel_details=pd.read_csv('hotel/Hotel_details.csv',delimiter=',')
hotel_rooms=pd.read_csv('hotel/Hotel_Room_attributes.csv',delimiter=',')
hotel_cost=pd.read_csv('hotel/hotels_RoomPrice.csv',delimiter=',')

# %%
hotel_details.head()
# Out:
#       id  hotelid                 hotelname                 address     city  \
# 0  46406  1771651  Mediteran Bungalow Galeb            Vukovarska 7     Omis
# 1  46407   177167             Hotel Polonia        Plac Teatralny 5    Torun
# 2  46408  1771675         Rifugio Sass Bece  Belvedere del Pordoi,1  Canazei
# 3  46409   177168            Madalena Hotel                 Mykonos  Mykonos
# 4  46410  1771718         Pension Morenfeld  Mair im Korn Strasse 2  Lagundo
#
#    country  zipcode   propertytype  starrating   latitude  longitude  Source  \
# 0  Croatia  21310.0  Holiday parks           4  43.440124  16.682505       2
# 1   Poland      NaN         Hotels           3  53.012329  18.603800       5
# 2    Italy  38032.0         Hotels           3  46.477920  11.813350       2
# 3   Greece  84600.0         Hotels           3  37.452316  25.329849       5
# 4    Italy  39022.0         Hotels           3  46.682780  11.131736       2
#
#                                                  url curr
# 0  https://www.booking.com/hotel/hr/bungalow-luxu...  EUR
# 1  https://www.agoda.com/en-gb/hotel-polonia/hote...  EUR
# 2  http://www.booking.com/hotel/it/rifugio-sass-b...  EUR
# 3  https://www.agoda.com/en-gb/madalena-hotel/hot...  EUR
# 4  http://www.booking.com/hotel/it/pension-morenf...  EUR

# %%
hotel_rooms.head()
# Out:
#          id  hotelcode                                      roomamenities  \
# 0  50677497     634876  Air conditioning: ;Alarm clock: ;Carpeting: ;C...
# 1  50672149    8328096  Air conditioning: ;Closet: ;Fireplace: ;Free W...
# 2  50643430    8323442  Air conditioning: ;Closet: ;Dishwasher: ;Firep...
# 3  50650317       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
# 4  50650318       7975  Air conditioning: ;Clothes rack: ;Coffee/tea m...
#
#                roomtype                                    ratedescription
# 0           Double Room       Room size: 15 m²/161 ft², Shower, 1 king bed
# 1         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 2         Vacation Home  Shower, Kitchenette, 2 bedrooms, 1 double bed ...
# 3  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds
# 4  Standard Triple Room    Room size: 20 m²/215 ft², Shower, 3 single beds

# %% [markdown]
# # Data Cleaning and transformations

# %%
del hotel_details['id']
del hotel_rooms['id']
del hotel_details['zipcode']

# %%
hotel_details=hotel_details.dropna()
hotel_rooms=hotel_rooms.dropna()

# %%
hotel_details.drop_duplicates(subset='hotelid',keep=False,inplace=True)

# %%
hotel=pd.merge(hotel_rooms,hotel_details,left_on='hotelcode',right_on='hotelid',how='inner')

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription', 'hotelid',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude', 'Source', 'url', 'curr'],
#       dtype='object')

# %%
del hotel['hotelid']
del hotel['url']
del hotel['curr']
del hotel['Source']

# %%
hotel.columns
# Out:
# Index(['hotelcode', 'roomamenities', 'roomtype', 'ratedescription',
#        'hotelname', 'address', 'city', 'country', 'propertytype', 'starrating',
#        'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# # Recommender system based only on City and ratings about the hotel

# %%
def citybased(city):
    hotel['city']=hotel['city'].str.lower()
    citybase=hotel[hotel['city']==city.lower()]
    citybase=citybase.sort_values(by='starrating',ascending=False)
    citybase.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    if(citybase.empty==0):
        hname=citybase[['hotelname','starrating','address','roomamenities','ratedescription']]
        return hname.head()
    else:
        print('No Hotels Available')

# %%
print('Top 5 hotels')
citybased('London')
# Out:
# Top 5 hotels
#                                               hotelname  starrating  \
# 69848                      Park Plaza London Park Royal           4
# 120285                       Novotel London Excel Hotel           4
# 63905                            Hard Rock Hotel London           4
# 69711                        Holiday Inn London Elstree           4
# 64612   DoubleTree by Hilton Hotel London - Westminster           4
#
#                        address  \
# 69848       628 Western Avenue
# 120285       7 Western Gateway
# 63905   Great Cumberland Place
# 69711           Barnet By Pass
# 64612     30 John Islip Street
#
#                                             roomamenities  \
# 69848   Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
# 120285  Air conditioning: ;Carpeting: ;Closet: ;Coffee...
# 63905   Air conditioning: ;Bathrobes: ;Carpeting: ;Clo...
# 69711   Additional toilet: ;Air conditioning: ;Carpeti...
# 64612   Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
#
#                                           ratedescription
# 69848   Room size: 24 m²/258 ft², Shower, 1 king bed a...
# 120285  Room size: 25 m²/269 ft², Non-smoking, Shower ...
# 63905   Room size: 28 m²/301 ft², Shower and bathtub, ...
# 69711   Room size: 25 m²/269 ft², City view, Non-smoki...
# 64612   Room size: 21 m²/226 ft², Non-smoking, Shower,...

# %%
room_no=[
     ('king',2),
   ('queen',2), 
    ('triple',3),
    ('master',3),
   ('family',4),
   ('murphy',2),
   ('quad',4),
   ('double-double',4),
   ('mini',2),
   ('studio',1),
    ('junior',2),
   ('apartment',4),
    ('double',2),
   ('twin',2),
   ('double-twin',4),
   ('single',1),
     ('diabled',1),
   ('accessible',1),
    ('suite',2),
    ('one',2)
   ]

# %%
def calc():
    guests_no=[]
    for i in range(hotel.shape[0]):
        temp=hotel['roomtype'][i].lower().split()
        flag=0
        for j in range(len(temp)):
            for k in range(len(room_no)):
                if temp[j]==room_no[k][0]:
                    guests_no.append(room_no[k][1])
                    flag=1
                    break
            if flag==1:
                break
        if flag==0:
            guests_no.append(2)
    hotel['guests_no']=guests_no

calc()

# %%
def pop_citybased(city,number):
    hotel['city']=hotel['city'].str.lower()
    popbased=hotel[hotel['city']==city.lower()]
    popbased=popbased[popbased['guests_no']==number].sort_values(by='starrating',ascending=False)
    popbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    if popbased.empty==True:
        print('Sorry No Hotels Available\n tune your constraints')
    else:
        return popbased[['hotelname','roomtype','guests_no','starrating','address','roomamenities','ratedescription']].head(10)

# %%
pop_citybased('London',4)
# Out:
#                                                 hotelname  \
# 968                      Holiday Inn London - Heathrow T5
# 129097        Best Western Plus London Croydon Aparthotel
# 53437                            Wimbledon Boutique Hotel
# 114332                                    Greenland Villa
# 115037  DoubleTree by Hilton Hotel London - Docklands ...
# 48488          The Park City Grand Plaza Kensington Hotel
# 112773                                The Cleveland Hotel
# 108956                     Mercure London Hyde Park Hotel
# 110049             Sheraton Skyline Hotel London Heathrow
# 54264                Pestana Chelsea Bridge Hotel And Spa
#
#                                  roomtype  guests_no  starrating  \
# 968                           Family Room          4           4
# 129097                               Quad          4           4
# 53437                         Family Room          4           4
# 114332                          Quad Room          4           4
# 115037            Two Bedroom Family Room          4           4
# 48488             Family Room - Room Only          4           4
# 112773                      Family Studio          4           4
# 108956                        Family Room          4           4
# 110049  Family Room, Guest room, 2 Double          4           4
# 54264                  Deluxe Family Room          4           4
#
#                             address  \
# 968                   Old Bath Road
# 129097          Dunheved Road South
# 53437                78 Worple Road
# 114332              9 Charlton Road
# 115037       265 Rotherhithe Street
# 48488          18-30 Lexham Gardens
# 112773       39-40 Cleveland Square
# 108956           8-14 Talbot Square
# 110049  Heathrow Airport, Bath Road
# 54264           354 Queenstown Road
#
#                                             roomamenities  \
# 968     Air conditioning: ;Alarm clock: ;Blackout curt...
# 129097  Air conditioning: ;Alarm clock: ;Closet: ;Clot...
# 53437   Air conditioning: ;Carpeting: ;Closet: ;Coffee...
# 114332  Air conditioning: ;Carpeting: ;Closet: ;Clothe...
# 115037  Air conditioning: ;Closet: ;Coffee/tea maker: ...
# 48488   Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# 112773  Air conditioning: ;Free Wi-Fi in all rooms!: ;...
# 108956  Air conditioning: ;Desk: ;Free Wi-Fi in all ro...
# 110049  Air conditioning: ;Alarm clock: ;Bathrobes: ;C...
# 54264   Air conditioning: ;Alarm clock: ;Bathrobes: ;B...
#
#                                           ratedescription
# 968     Room size: 25 m²/269 ft², Non-smoking, Separat...
# 129097  Room size: 20 m²/215 ft², Street view, Non-smo...
# 53437   Room size: 22 m²/237 ft², Street view, Non-smo...
# 114332  Room size: 15 m²/161 ft², Non-smoking, Shower,...
# 115037  Room size: 60 m²/646 ft², Lake view, Non-smoki...
# 48488       Free Wi-Fi, Extra low price! (non-refundable)
# 112773      Free Wi-Fi, Extra low price! (non-refundable)
# 108956  Room size: 31 m²/334 ft², Non-smoking, 1 singl...
# 110049     Non-smoking, Shower and bathtub, 2 double beds
# 54264   Room size: 30 m²/323 ft², Non-smoking, Separat...

# %%
hotel['roomamenities']=hotel['roomamenities'].str.replace(': ;',',')

# %%
hotel
# Out:
#         hotelcode                                      roomamenities  \
# 0          634876  air conditioning,alarm clock,carpeting,closet,...
# 1            7975  air conditioning,clothes rack,coffee/tea maker...
# 2            7975  air conditioning,clothes rack,coffee/tea maker...
# 3            7975  air conditioning,clothes rack,coffee/tea maker...
# 4            7975  air conditioning,clothes rack,heating,in-room ...
# ...           ...                                                ...
# 145420     268416  air conditioning,alarm clock,carpeting,closet,...
# 145421     268416  air conditioning,alarm clock,carpeting,closet,...
# 145422     268416  air conditioning,alarm clock,carpeting,closet,...
# 145423     268416  air conditioning,free wi-fi in all rooms!,in-r...
# 145424     268416  air conditioning,free wi-fi in all rooms!,in-r...
#
#                     roomtype  \
# 0                Double Room
# 1       Standard Triple Room
# 2       Standard Triple Room
# 3       Standard Triple Room
# 4         Deluxe Triple Room
# ...                      ...
# 145420             Twin Room
# 145421             Twin Room
# 145422             Twin Room
# 145423         Twin Standard
# 145424       Double Standard
#
#                                           ratedescription  \
# 0            Room size: 15 m²/161 ft², Shower, 1 king bed
# 1         Room size: 20 m²/215 ft², Shower, 3 single beds
# 2         Room size: 20 m²/215 ft², Shower, 3 single beds
# 3         Room size: 20 m²/215 ft², Shower, 3 single beds
# 4                   Shower, 1 single bed and 1 double bed
# ...                                                   ...
# 145420  Room size: 17 m²/183 ft², Non-smoking, Shower,...
# 145421  Room size: 17 m²/183 ft², Non-smoking, Shower,...
# 145422  Room size: 17 m²/183 ft², Non-smoking, Shower,...
# 145423  Pay nothing until November 21, 2019, Free Wi-F...
# 145424  Pay nothing until November 21, 2019, Free Wi-F...
#
#                                    hotelname                      address  \
# 0                        The Old Cider House             25 Castle Street
# 1                        Apollo Hotel London  64-66 Queensborough Terrace
# 2                        Apollo Hotel London  64-66 Queensborough Terrace
# 3                        Apollo Hotel London  64-66 Queensborough Terrace
# 4                        Apollo Hotel London  64-66 Queensborough Terrace
# ...                                      ...                          ...
# 145420  Sure Hotel by Best Western Newcastle            358 Westgate Road
# 145421  Sure Hotel by Best Western Newcastle            358 Westgate Road
# 145422  Sure Hotel by Best Western Newcastle            358 Westgate Road
# 145423  Sure Hotel by Best Western Newcastle            358 Westgate Road
# 145424  Sure Hotel by Best Western Newcastle            358 Westgate Road
#
#                        city         country propertytype  starrating  \
# 0             nether stowey  United Kingdom       Hotels           4
# 1                    london  United Kingdom       Hotels           2
# 2                    london  United Kingdom       Hotels           2
# 3                    london  United Kingdom       Hotels           2
# 4                    london  United Kingdom       Hotels           2
# ...                     ...             ...          ...         ...
# 145420  newcastle-upon-tyne  United Kingdom       Hotels           3
# 145421  newcastle-upon-tyne  United Kingdom       Hotels           3
# 145422  newcastle-upon-tyne  United Kingdom       Hotels           3
# 145423  newcastle-upon-tyne  United Kingdom       Hotels           3
# 145424  newcastle-upon-tyne  United Kingdom       Hotels           3
#
#          latitude  longitude  guests_no
# 0       51.150921  -3.158470          2
# 1       51.511234  -0.185117          3
# 2       51.511234  -0.185117          3
# 3       51.511234  -0.185117          3
# 4       51.511234  -0.185117          3
# ...           ...        ...        ...
# 145420  54.972672  -1.634396          2
# 145421  54.972672  -1.634396          2
# 145422  54.972672  -1.634396          2
# 145423  54.972672  -1.634396          2
# 145424  54.972672  -1.634396          2
#
# [145425 rows x 13 columns]

# %%
def requirementbased(city,number,features):
    hotel['city']=hotel['city'].str.lower()
    hotel['roomamenities']=hotel['roomamenities'].str.lower()
    features=features.lower()
    features_tokens=word_tokenize(features)  
    sw = stopwords.words('english')
    lemm = WordNetLemmatizer()
    f1_set = {w for w in features_tokens if not w in sw}
    f_set=set()
    for se in f1_set:
        f_set.add(lemm.lemmatize(se))
    reqbased=hotel[hotel['city']==city.lower()]
    reqbased=reqbased[reqbased['guests_no']==number]
    reqbased=reqbased.set_index(np.arange(reqbased.shape[0]))
    l1 =[];l2 =[];cos=[];
    #print(reqbased['roomamenities'])
    for i in range(reqbased.shape[0]):
        temp_tokens=word_tokenize(reqbased['roomamenities'][i])
        temp1_set={w for w in temp_tokens if not w in sw}
        temp_set=set()
        for se in temp1_set:
            temp_set.add(lemm.lemmatize(se))
        rvector = temp_set.intersection(f_set)
        #print(rvector)
        cos.append(len(rvector))
    reqbased['similarity']=cos
    reqbased=reqbased.sort_values(by='similarity',ascending=False)
    reqbased.drop_duplicates(subset='hotelcode',keep='first',inplace=True)
    return reqbased[['hotelname','roomtype','guests_no','starrating','address','roomamenities','ratedescription','similarity']].head(5)

# %% [markdown]
# # Requirement And special needs based Recommender

# %%
requirementbased('London',1,'I need a extra toilet and room should be completely air conditioned.I should have a bathrobe.')
# Out:
#                                 hotelname  \
# 245            The Colonnade London Hotel
# 256              Park International Hotel
# 1018  Holiday Inn London - Heathrow Ariel
# 485                            Saba Hotel
# 487         Holiday Inn Express Dunstable
# 233               Best Western Palm Hotel
# 460            Park Plaza London Waterloo
# 285                 The Springfield Hotel
# 538           The Collective Canary Wharf
# 1025       Holiday Inn Express Park Royal
#
#                                            roomtype  guests_no  starrating  \
# 245                                          Studio          1           4
# 256                            Standard Single Room          1           4
# 1018                 1 Single Bed 1 Per Non-Smoking          1           3
# 485                                 Single En Suite          1           3
# 487   1 Bedroom Mobility Accessible Tub Non-Smoking          1           4
# 233            Standard Room With Three Single Beds          1           3
# 460                           Executive Studio Twin          1           4
# 285                                     Single Room          1           2
# 538                       Comfy Studio - High Floor          1           4
# 1025                      2 Single Beds Non-smoking          1           3
#
#                           address  \
# 245         2 Warrington Crescent
# 256         117-129 Cromwell Road
# 1018                118 Bath Road
# 485   101-103 Shepherds Bush Road
# 487        Vinci Site London Road
# 233              64-76 Hendon Way
# 460               6 Hercules Road
# 285            154 Sussex Gardens
# 538         20 Crossharbour Plaza
# 1025     Victoria RoadNorth Acton
#
#                                           roomamenities  \
# 245   additional toilet,air conditioning,alarm clock...
# 256   additional toilet,air conditioning,blackout cu...
# 1018  additional toilet,air conditioning,carpeting,c...
# 485   additional toilet,air conditioning,carpeting,c...
# 487   additional toilet,air conditioning,carpeting,c...
# 233   additional toilet,air conditioning,carpeting,c...
# 460   air conditioning,alarm clock,bathrobes,carpeti...
# 285   additional toilet,air conditioning,alarm clock...
# 538   air conditioning,bathrobes,free wi-fi in all r...
# 1025  air conditioning,alarm clock,carpeting,closet,...
#
#                                         ratedescription  similarity
# 245   Room size: 28 m²/301 ft², Balcony/terrace, Non...           4
# 256   Room size: 11 m²/118 ft², Non-smoking, Shower,...           3
# 1018  Room size: 25 m²/269 ft², Non-smoking, Shower ...           3
# 485                   Non-smoking, Shower, 1 single bed           3
# 487   Room size: 25 m²/269 ft², Non-smoking, Shower,...           3
# 233    Room size: 28 m²/301 ft², Bathtub, 3 single beds           3
# 460   Room size: 25 m²/269 ft², City view, Non-smoki...           3
# 285                   Street view, Shower, 1 single bed           3
# 538              Room size: 20 m²/215 ft², 1 double bed           3
# 1025  Room size: 25 m²/269 ft², Non-smoking, Shower,...           3

# %%
import pickle

with open("hotel/hotel.pkl", 'wb') as file:
    pickle.dump(hotel, file)
